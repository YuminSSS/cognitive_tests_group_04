# %% [markdown]
# # Approximate Number System (ANS) test
#
# This program runs the ANS test, upoloading your results to an online spreadsheet.
#
# Select **Run** > **Run All Cells** from the menu to run the test.

# %%
from ANS_final import*
# Run the full test with the provided user ID
run_full_test()
# Out:
# Your total score is: 34 / 64 (53.12%)
# '
# Feel free to compare you score with other data!
